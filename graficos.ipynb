# %%
import pandas as pd
import matplotlib.pyplot as plt 

amdprocess = pd.read_csv('./amd_processors.csv')
print(amdprocess.head(5))

bench = pd.read_csv("cpu_benchmarks.csv")
print(bench.head(10))

intelark = pd.read_csv("intel_ark_processors.csv")
print(intelark.head(10))

intelprocess = pd.read_csv("intel_processors.csv")
print(intelprocess.head(10))

comp11 = pd.read_csv("Windows11_supported_intel_processors.csv")
print(comp11.head(10))

amdprocess.plot(kind = 'bar')
plt.show()
# Out:
#    id  cores  threads                         name launch_date  lithography  \
# 0   1   16.0     32.0            AMD Ryzen 9 5950X   11/5/2020          7.0
# 1   2   12.0     24.0            AMD Ryzen 9 5900X   11/5/2020          7.0
# 2   3   12.0     24.0  AMD Ryzen 9 5900 (OEM Only)   1/12/2021          7.0
# 3   4    8.0     16.0            AMD Ryzen 7 5800X   11/5/2020          7.0
# 4   5    8.0     16.0  AMD Ryzen 7 5800 (OEM Only)   1/12/2021          7.0
#
#    base_frequency  turbo_frequency  cache_l1  cache_l2  cache_l3    tdp  \
# 0            3400           4900.0       NaN    8192.0   65536.0  105.0
# 1            3700           4800.0       NaN    6144.0   65536.0  105.0
# 2            3000           4700.0       NaN    6144.0   65536.0   65.0
# 3            3800           4700.0       NaN    4096.0   32768.0  105.0
# 4            3400           4600.0       NaN    4096.0   32768.0   65.0
#
#                      product_line socket memory_type  \
# 0  AMD Ryzen 9 Desktop Processors    AM4        DDR4
# 1  AMD Ryzen 9 Desktop Processors    AM4        DDR4
# 2  AMD Ryzen 9 Desktop Processors    AM4        DDR4
# 3  AMD Ryzen 7 Desktop Processors    AM4        DDR4
# 4  AMD Ryzen 7 Desktop Processors    AM4        DDR4
#
#                                     url vertical_segment  max_temp  \
# 0  https://www.amd.com/en/product/10456  Boxed Processor      90.0
# 1  https://www.amd.com/en/product/10461  Boxed Processor      90.0
# 2  https://www.amd.com/en/product/10796          Desktop      95.0
# 3  https://www.amd.com/en/product/10466  Boxed Processor      90.0
# 4  https://www.amd.com/en/product/10791          Desktop      95.0
#
#    max_memory_speed    sku
# 0            3200.0  10456
# 1            3200.0  10461
# 2            3200.0  10796
# 3            3200.0  10466
# 4            3200.0  10791
#    id manufacturer    sku  rating  \
# 0   1          amd  10456   46113
# 1   2          amd  10461   39634
# 2   3          amd  10466   28481
# 3   4          amd  10471   22165
# 4   5          amd   9931   32902
# 5   6          amd   9941   23890
# 6   7          amd   9936   18822
# 7   8          amd  10181   86067
# 8   9          amd  10176   63383
# 9  10          amd  10186   40293
#
#                                                  url
# 0  https://www.cpubenchmark.net/cpu.php?cpu=AMD+R...
# 1  https://www.cpubenchmark.net/cpu.php?cpu=AMD+R...
# 2  https://www.cpubenchmark.net/cpu.php?cpu=AMD+R...
# 3  https://www.cpubenchmark.net/cpu.php?cpu=AMD+R...
# 4  https://www.cpubenchmark.net/cpu.php?cpu=AMD+R...
# 5  https://www.cpubenchmark.net/cpu.php?cpu=AMD+R...
# 6  https://www.cpubenchmark.net/cpu.php?cpu=AMD+R...
# 7  https://www.cpubenchmark.net/cpu.php?cpu=AMD+R...
# 8  https://www.cpubenchmark.net/cpu.php?cpu=AMD+R...
# 9  https://www.cpubenchmark.net/cpu.php?cpu=AMD+R...
#    id  cores  threads                 name processor_number launch_date  \
# 0   1    4.0      8.0   Intel Itanium 9750             9750  2017-05-01
# 1   2    8.0     16.0   Intel Itanium 9760             9760  2017-05-01
# 2   3    4.0      8.0   Intel Itanium 9720             9720  2017-05-01
# 3   4    8.0     16.0   Intel Itanium 9740             9740  2017-05-01
# 4   5    4.0      8.0   Intel Itanium 9520             9520  2012-11-01
# 5   6    8.0     16.0   Intel Itanium 9540             9540  2012-11-01
# 6   7    4.0      8.0   Intel Itanium 9550             9550  2012-11-01
# 7   8    2.0      4.0  Intel Itanium 9152M            9152M  2007-11-01
# 8   9    2.0      4.0  Intel Itanium 9150N            9150N  2007-11-01
# 9  10    2.0      4.0  Intel Itanium 9140N            9140N  2007-11-01
#
#    lithography  bus_speed  base_frequency  turbo_frequency  ...  product_line  \
# 0         32.0        6.4          2530.0              NaN  ...           NaN
# 1         32.0        6.4          2660.0              NaN  ...           NaN
# 2         32.0        6.4          1730.0              NaN  ...           NaN
# 3         32.0        6.4          2130.0              NaN  ...           NaN
# 4         32.0        6.4          1730.0              NaN  ...           NaN
# 5         32.0        6.4          2130.0              NaN  ...           NaN
# 6         32.0        6.4          2400.0              NaN  ...           NaN
# 7         90.0      667.0          1660.0              NaN  ...           NaN
# 8         90.0      533.0          1600.0              NaN  ...           NaN
# 9         90.0      533.0          1600.0              NaN  ...           NaN
#
#     socket  memory_type                                                url  \
# 0  LGA1248          NaN  https://ark.intel.com/content/www/us/en/ark/pr...
# 1  LGA1248          NaN  https://ark.intel.com/content/www/us/en/ark/pr...
# 2  LGA1248          NaN  https://ark.intel.com/content/www/us/en/ark/pr...
# 3  LGA1248          NaN  https://ark.intel.com/content/www/us/en/ark/pr...
# 4  LGA1248          NaN  https://ark.intel.com/content/www/us/en/ark/pr...
# 5  LGA1248          NaN  https://ark.intel.com/content/www/us/en/ark/pr...
# 6  LGA1248          NaN  https://ark.intel.com/content/www/us/en/ark/pr...
# 7      NaN          NaN  https://ark.intel.com/content/www/us/en/ark/pr...
# 8  PPGA611          NaN  https://ark.intel.com/content/www/us/en/ark/pr...
# 9  PPGA611          NaN  https://ark.intel.com/content/www/us/en/ark/pr...
#
#    vertical_segment  max_memory_size        status max_temp     sku  \
# 0            Server              NaN  Discontinued     95.0  122884
# 1            Server              NaN      Launched     95.0  122883
# 2            Server              NaN      Launched     95.0  122882
# 3            Server              NaN      Launched     95.0  122880
# 4            Server              NaN  Discontinued     95.0   71702
# 5            Server              NaN  Discontinued     95.0   71701
# 6            Server              NaN  Discontinued     95.0   71700
# 7            Server              NaN  Discontinued     76.0   34655
# 8            Server              NaN  Discontinued     76.0   31796
# 9            Server              NaN  Discontinued     76.0   31795
#
#       package_size
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7  113mm x 48.26mm
# 8  113mm x 48.26mm
# 9  113mm x 48.26mm
#
# [10 rows x 25 columns]
#    id  cores  threads                  name processor_number launch_date  \
# 0   1      2      2.0      Intel Atom C2338            C2338  2013-08-01
# 1   2      2      2.0      Intel Atom C2350            C2350  2013-08-01
# 2   3      2      2.0      Intel Atom C2358            C2358  2013-08-01
# 3   4      4      4.0      Intel Atom C2518            C2518  2013-08-01
# 4   5      4      8.0   Intel Core i7-8709G         i7-8709G  2018-02-01
# 5   6      4      8.0    Intel Core i7-6700          i7-6700  2015-08-01
# 6   7      4      8.0  Intel Core i7-4720HQ        i7-4720HQ  2015-02-01
# 7   8      4      8.0  Intel Core i7-4722HQ        i7-4722HQ  2015-02-01
# 8   9      2      4.0   Intel Core i7-5550U         i7-5550U  2015-02-01
# 9  10      2      4.0   Intel Core i7-5557U         i7-5557U  2015-02-01
#
#    lithography  bus_speed  base_frequency  turbo_frequency  ...     socket  \
# 0         22.0        NaN          1700.0           2000.0  ...  FCBGA1283
# 1         22.0        NaN          1700.0           2000.0  ...  FCBGA1283
# 2         22.0        NaN          1700.0           2000.0  ...  FCBGA1283
# 3         22.0        NaN          1700.0              NaN  ...  FCBGA1283
# 4         14.0        8.0          3100.0           4100.0  ...    BGA2270
# 5         14.0        8.0          3400.0           4000.0  ...  FCLGA1151
# 6         22.0        5.0          2600.0           3600.0  ...  FCBGA1364
# 7         22.0        5.0          2400.0           3400.0  ...  FCBGA1364
# 8         14.0        5.0          2000.0           3000.0  ...  FCBGA1168
# 9         14.0        5.0          3100.0           3400.0  ...  FCBGA1168
#
#                                memory_type  \
# 0                          DDR3/DDR3L 1333
# 1                          DDR3/DDR3L 1333
# 2                          DDR3/DDR3L 1333
# 3                          DDR3/DDR3L 1333
# 4                                DDR4-2400
# 5  DDR4-1866/2133, DDR3L-1333/1600 @ 1.35V
# 6                          DDR3L 1333/1600
# 7                          DDR3L 1333/1600
# 8        DDR3L 1333/1600, LPDDR3 1600/1866
# 9        DDR3L 1333/1600, LPDDR3 1600/1866
#
#                                                  url  vertical_segment  \
# 0  https://www.intel.com/content/www/us/en/produc...          Embedded
# 1  https://www.intel.com/content/www/us/en/produc...            Server
# 2  https://www.intel.com/content/www/us/en/produc...          Embedded
# 3  https://www.intel.com/content/www/us/en/produc...          Embedded
# 4  https://www.intel.com/content/www/us/en/produc...            Mobile
# 5  https://www.intel.com/content/www/us/en/produc...           Desktop
# 6  https://www.intel.com/content/www/us/en/produc...            Mobile
# 7  https://www.intel.com/content/www/us/en/produc...            Mobile
# 8  https://www.intel.com/content/www/us/en/produc...            Mobile
# 9  https://www.intel.com/content/www/us/en/produc...            Mobile
#
#    max_memory_size        status max_temp     sku           package_size  \
# 0       16777216.0      Launched      NaN   77976          34 mm x 28 mm
# 1       16777216.0      Launched     98.0   77977          34 mm x 28 mm
# 2       16777216.0      Launched      NaN   77978          34 mm x 28 mm
# 3       33554432.0      Launched      NaN   77979          34 mm x 28 mm
# 4       67108864.0  Discontinued    100.0  130407          31mm x 58.5mm
# 5       67108864.0      Launched     71.0   88196        37.5mm x 37.5mm
# 6       33554432.0  Discontinued    100.0   78934  37.5mm x 32mm x 1.6mm
# 7       33554432.0  Discontinued    100.0   78935  37.5mm x 32mm x 1.6mm
# 8       16777216.0  Discontinued    105.0   84992     40mm x24mm x 1.3mm
# 9       16777216.0  Discontinued    105.0   84993     40mm x24mm x 1.3mm
#
#                                             fullname
# 0    Intel Atom Processor C2338 (1M Cache, 1.70 GHz)
# 1    Intel Atom Processor C2350 (1M Cache, 1.70 GHz)
# 2    Intel Atom Processor C2358 (1M Cache, 1.70 GHz)
# 3    Intel Atom Processor C2518 (2M Cache, 1.70 GHz)
# 4  Intel Core i7-8709G Processor with Radeon RX V...
# 5  Intel Core i7-6700 Processor (8M Cache, up to ...
# 6  Intel Core i7-4720HQ Processor (6M Cache, up t...
# 7  Intel Core i7-4722HQ Processor (6M Cache, up t...
# 8  Intel Core i7-5550U Processor (4M Cache, up to...
# 9  Intel Core i7-5557U Processor (4M Cache, up to...
#
# [10 rows x 26 columns]
#         processor_name  Unnamed: 1
# 0   Intel Atom x6200FE         NaN
# 1    Intel Atom x6211E         NaN
# 2   Intel Atom x6212RE         NaN
# 3    Intel Atom x6413E         NaN
# 4   Intel Atom x6414RE         NaN
# 5    Intel Atom x6425E         NaN
# 6   Intel Atom x6425RE         NaN
# 7   Intel Atom x6427FE         NaN
# 8   Intel Celeron 6305         NaN
# 9  Intel Celeron 3867U         NaN
